# %% [markdown]
# <a href="https://colab.research.google.com/github/ss01-0-0/pilot/blob/main/DAY%201%20TESTING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import pandas as pd
import matplotlib as plt

data=yf.download("AAPL",start="2020-01-01",end="2026-01-01")
print(data.head())

# %% [markdown]
# What did I learn?
# - well, i never new that i have to import certain libraries into python to access their data.
# - never new what .head does, now i know it takes the first 5 items from the dataset.
#
# future plans:
# - will look at python libraries in more depth
# - still need to start learning c++
